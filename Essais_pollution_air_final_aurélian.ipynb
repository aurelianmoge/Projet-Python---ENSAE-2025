# %%
import requests
import zipfile
import openpyxl

import pandas as pd
import geopandas as gpd

# %%
## On importe la pollution de l'air

pollution_1er_janvier = pd.read_csv("Pollution_air_1er_janvier.csv", sep = ";")

# %%
# On ne garde que l'IDF

pollution_1er_janvier_idf = pollution_1er_janvier.copy()
pollution_1er_janvier_idf = pollution_1er_janvier_idf[pollution_1er_janvier_idf["Organisme"] in ["AIRPARIF", "ZAG PARIS", "ZR ILE-DE-FRANCE"]

# %%
pollution_1er_janvier_idf.shape
# Out:
# (4200, 23)
